# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Dataset.csv")
# Out:
# /tmp/ipykernel_11561/362287225.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Dataset.csv")

# %%
df.head()
# Out:
#   policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 0   ID00001       0.515874        0.05             0.644231           C1
# 1   ID00002       0.672619        0.02             0.375000           C2
# 2   ID00003       0.841110        0.02             0.384615           C3
# 3   ID00004       0.900277        0.11             0.432692           C4
# 4   ID00005       0.596403        0.11             0.634615           C5
#
#   population_density  make  is_claim segment model  ...  \
# 0               4990     1         0       A    M1  ...
# 1             27003"     1         0       A    M1  ...
# 2               4076     1         0       A    M1  ...
# 3             21622"     1         0      C1    M2  ...
# 4              34738     2         0       A    M3  ...
#
#   is_rear_window_defogger is_brake_assist is_power_door_locks  \
# 0                      No              No                  No
# ...

# %%
df["population_density"]
# Out:
# 0          4990
# 1        27003"
# 2          4076
# 3        21622"
# 4         34738
#           ...
# 30095      8794
# 30096     27003
# 30097     27003
# 30098     16206
# 30099     34738
# Name: population_density, Length: 30100, dtype: object

# %%
df["population_density"].count()
# Out:
# 30100

# %%
new_list = list()

# %%
translation_table = str.maketrans({'"': None, '_': None})

# %%
df["population_density"] = [str(item).translate(translation_table) for item in df["population_density"]]

# %%
df.head()
# Out:
#   policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 0   ID00001       0.515874        0.05             0.644231           C1
# 1   ID00002       0.672619        0.02             0.375000           C2
# 2   ID00003       0.841110        0.02             0.384615           C3
# 3   ID00004       0.900277        0.11             0.432692           C4
# 4   ID00005       0.596403        0.11             0.634615           C5
#
#   population_density  make  is_claim segment model  ...  \
# 0               4990     1         0       A    M1  ...
# 1              27003     1         0       A    M1  ...
# 2               4076     1         0       A    M1  ...
# 3              21622     1         0      C1    M2  ...
# 4              34738     2         0       A    M3  ...
#
#   is_rear_window_defogger is_brake_assist is_power_door_locks  \
# 0                      No              No                  No
# ...

# %%
df["population_density"] = df["population_density"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30100 entries, 0 to 30099
# Data columns (total 44 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   policy_id                         30100 non-null  object
#  1   policy_tenure                     30100 non-null  float64
#  2   age_of_car                        30100 non-null  float64
#  3   age_of_policyholder               30100 non-null  float64
#  4   area_cluster                      30100 non-null  object
#  5   population_density                30100 non-null  int64
#  6   make                              30100 non-null  int64
#  7   is_claim                          30100 non-null  int64
#  8   segment                           30100 non-null  object
#  9   model                             30100 non-null  object
#  10  fuel_type                         30100 non-null  object
# ...

# %%
# list_new = list()
# for val in df["population_density"]:
#     print(val)
#     print(type(val))
   
#     print(val.split('"'))
#     print(type(val.split('"')))
#     # list_new.append(val.split('"')[0])
