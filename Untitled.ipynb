# %% [markdown]
# import pandas as pd
# import numpy as np

# %%
df = pd.read_csv('./Dataset.csv')
pd.set_option("display.max_columns",None)
df.head()
# Out:
# /tmp/ipykernel_15024/2355730272.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./Dataset.csv')
#   policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 0   ID00001       0.515874        0.05             0.644231           C1
# 1   ID00002       0.672619        0.02             0.375000           C2
# 2   ID00003       0.841110        0.02             0.384615           C3
# 3   ID00004       0.900277        0.11             0.432692           C4
# 4   ID00005       0.596403        0.11             0.634615           C5
#
#   population_density  make  is_claim segment model fuel_type     max_torque  \
# 0               4990     1         0       A    M1       CNG   60Nm@3500rpm
# 1             27003"     1         0       A    M1       CNG   60Nm@3500rpm
# 2               4076     1         0       A    M1       CNG   60Nm@3500rpm
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30100 entries, 0 to 30099
# Data columns (total 44 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   policy_id                         30100 non-null  object
#  1   policy_tenure                     30100 non-null  float64
#  2   age_of_car                        30100 non-null  float64
#  3   age_of_policyholder               30100 non-null  float64
#  4   area_cluster                      30100 non-null  object
#  5   population_density                30100 non-null  object
#  6   make                              30100 non-null  int64
#  7   is_claim                          30100 non-null  int64
#  8   segment                           30100 non-null  object
#  9   model                             30100 non-null  object
#  10  fuel_type                         30100 non-null  object
# ...

# %%
df.height.unique()
# Out:
# array([1475, 1515, 1490, 1635, 1523, 1530, 1500, 1675, 1501, 1825, 1606])

# %%
df.width.unique()
# Out:
# array(['1515(mm)', '1735(mm)', '1579(mm)', '1790(mm)', '1755(mm)',
#        '1745(mm)', '1620(mm)', '1695(mm)', '1475(mm)', '1811(mm)'],
#       dtype=object)

# %%
df.is_claim.unique()
# Out:
# array([0, 1])

# %%
df.Length.unique()
# Out:
# array(['(mm)3445', '(mm)3995', '(mm)3731', '(mm)4300', '(mm)3990',
#        '(mm)3845', '(mm)3655', '(mm)3675', '(mm)3993'], dtype=object)

# %%
for i in df.turning_radius:
    print(i)

# %%
(df.population_density == isnum()).count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 (df.population_density == isnum()).count()
#
# NameError: name 'isnum' is not defined

# %%
(df.age_of_car < 1).count()
# Out:
# 30100

# %%
df.describe()
# Out:
#        policy_tenure    age_of_car  age_of_policyholder          make  \
# count   30100.000000  30100.000000         30100.000000  30100.000000
# mean        0.612097      0.069436             0.469028      1.758272
# std         0.414670      0.056833             0.122673      1.136681
# min         0.002739      0.000000             0.288462      1.000000
# 25%         0.207099      0.020000             0.365385      1.000000
# 50%         0.575252      0.060000             0.451923      1.000000
# 75%         1.040013      0.110000             0.548077      3.000000
# max         1.376478      1.000000             0.971154      5.000000
#
#            is_claim       airbags  displacement      cylinder      gear_box  \
# count  30100.000000  30100.000000  30100.000000  30100.000000  30100.000000
# mean       0.064086      3.122757   1160.974784      3.625748      5.241462
# std        0.244911      1.825846    265.800505      0.483937      0.427977
# ...
